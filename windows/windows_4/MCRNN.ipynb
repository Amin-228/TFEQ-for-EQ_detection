# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os,time,pickle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from joblib import dump, load
from utils import data_process, visualize
from utils.utils import train, test, summary, setup_seed
from utils.MCRNN import MCRNN
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "6"

# %%
data = np.load("./data_4/data_train.npy", allow_pickle=True)
x_train = data.item().get("x_train")
y_train = data.item().get("y_train")
data = np.load("./data_4/data_test.npy", allow_pickle=True)
x_test = data.item().get("x_test")
y_test = data.item().get("y_test")
x_train=x_train.transpose((0,2,1))
x_test=x_test.transpose((0,2,1))

x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).long()
traindata = TensorDataset(x_train, y_train)
testdata = TensorDataset(x_test, y_test)
train_loader = DataLoader(traindata, batch_size=256, shuffle=True)
test_loader = DataLoader(testdata, batch_size=256, shuffle=True)

# %%
class Conv(nn.Module):
    def __init__(self, ):
        super(Conv, self).__init__()
        self.conv_1 = nn.Conv1d(in_channels=1,  out_channels=32, kernel_size=3, stride=3)
        self.conv_2 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=3)
        self.conv_3 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3)
        self.MaxPool = nn.MaxPool1d(2)
        self.Flatten = torch.nn.Flatten()

    def forward(self, x):
        out = F.relu(self.conv_1(x))
        out = F.relu(self.conv_2(out))
        out = F.relu(self.conv_3(out))
        out = self.MaxPool(out)
        out = self.Flatten(out)
        return out


class MCRNN(nn.Module):
    def __init__(self, ):
        super(MCRNN, self).__init__()
        self.conv_x = Conv()
        self.conv_y = Conv()
        self.conv_z = Conv()
        self.rnn = nn.RNN(input_size=2016, hidden_size=64)
        self.fla = nn.Flatten()
        self.fc1 = nn.Linear(64, 100)
        self.fc2 = nn.Linear(100, 2)

    def forward(self, data):
        x, y, z = data[:, 0, :], data[:, 1, :], data[:, 2, :]
        x = x.view(-1, 1, x.shape[-1])
        y = y.view(-1, 1, y.shape[-1])
        z = z.view(-1, 1, z.shape[-1])
        x_out = self.conv_x(x)
        y_out = self.conv_y(y)
        z_out = self.conv_z(z)
        new_feature = torch.cat([x_out, y_out, z_out], dim=1)
        new_feature = new_feature.view(-1, 1, new_feature.shape[-1])
        out, _ = self.rnn(new_feature)
        out = self.fla(out)
        out = F.relu(self.fc1(out))
        out = self.fc2(out)
        return F.log_softmax(out, dim=1)

# %%
data=torch.rand(16,3,400)
model=MCRNN()
model(data).shape
# Out:
# torch.Size([16, 2])

# %%
# %%time
setup_seed(42)
model = MCRNN().cuda()
L = []
test_hist = []
optimizer = optim.Adam(model.parameters(), lr=0.001)
for epoch in range(1, 100 + 1):
    start = time.time()
    loss = train(model, train_loader, optimizer, epoch)
    L.append(loss)
    print("time {:.1f} sec:".format(time.time() - start))
    acc = test(model, test_loader)
    test_hist.append(acc)
# Out:
# Train Epoch: 1, Average Loss: 0.3891
# time 1.2 sec:
# Test set: Average loss: 0.3539, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 2, Average Loss: 0.3488
# time 1.2 sec:
# Test set: Average loss: 0.3509, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 3, Average Loss: 0.3481
# time 1.2 sec:
# Test set: Average loss: 0.3541, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 4, Average Loss: 0.3515
# time 1.1 sec:
# Test set: Average loss: 0.3511, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 5, Average Loss: 0.3498
# time 1.1 sec:
# Test set: Average loss: 0.3511, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 6, Average Loss: 0.3504
# time 1.2 sec:
# Test set: Average loss: 0.3510, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 7, Average Loss: 0.3490
# time 1.1 sec:
# Test set: Average loss: 0.3520, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 8, Average Loss: 0.3518
# time 1.1 sec:
# Test set: Average loss: 0.3512, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 9, Average Loss: 0.3493
# time 1.1 sec:
# Test set: Average loss: 0.3514, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 10, Average Loss: 0.3490
# time 1.1 sec:
# Test set: Average loss: 0.3507, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 11, Average Loss: 0.3494
# time 1.1 sec:
# Test set: Average loss: 0.3449, Accuracy: 1837/2069 (88.79%)
#
# Train Epoch: 12, Average Loss: 0.3456
# time 1.1 sec:
# Test set: Average loss: 0.3344, Accuracy: 1844/2069 (89.13%)
#
# Train Epoch: 13, Average Loss: 0.2327
# time 1.1 sec:
# Test set: Average loss: 0.1737, Accuracy: 1954/2069 (94.44%)
#
# Train Epoch: 14, Average Loss: 0.1943
# time 1.1 sec:
# Test set: Average loss: 0.1612, Accuracy: 1961/2069 (94.78%)
#
# Train Epoch: 15, Average Loss: 0.1409
# time 1.1 sec:
# Test set: Average loss: 0.1198, Accuracy: 1984/2069 (95.89%)
#
# Train Epoch: 16, Average Loss: 0.1165
# time 1.1 sec:
# Test set: Average loss: 0.1115, Accuracy: 1996/2069 (96.47%)
#
# Train Epoch: 17, Average Loss: 0.1142
# time 1.1 sec:
# Test set: Average loss: 0.1037, Accuracy: 2000/2069 (96.67%)
#
# Train Epoch: 18, Average Loss: 0.0997
# time 1.3 sec:
# Test set: Average loss: 0.0952, Accuracy: 2008/2069 (97.05%)
#
# Train Epoch: 19, Average Loss: 0.0957
# time 1.1 sec:
# Test set: Average loss: 0.1083, Accuracy: 2002/2069 (96.76%)
#
# Train Epoch: 20, Average Loss: 0.1196
# time 1.1 sec:
# Test set: Average loss: 0.0932, Accuracy: 2006/2069 (96.96%)
#
# Train Epoch: 21, Average Loss: 0.0897
# time 1.2 sec:
# Test set: Average loss: 0.0917, Accuracy: 2010/2069 (97.15%)
#
# Train Epoch: 22, Average Loss: 0.0843
# time 1.2 sec:
# Test set: Average loss: 0.0827, Accuracy: 2016/2069 (97.44%)
#
# Train Epoch: 23, Average Loss: 0.0830
# time 1.1 sec:
# Test set: Average loss: 0.0785, Accuracy: 2019/2069 (97.58%)
#
# Train Epoch: 24, Average Loss: 0.0761
# time 1.2 sec:
# Test set: Average loss: 0.0872, Accuracy: 2014/2069 (97.34%)
#
# Train Epoch: 25, Average Loss: 0.0749
# time 1.1 sec:
# Test set: Average loss: 0.0780, Accuracy: 2019/2069 (97.58%)
#
# Train Epoch: 26, Average Loss: 0.0786
# time 1.1 sec:
# Test set: Average loss: 0.0751, Accuracy: 2023/2069 (97.78%)
#
# Train Epoch: 27, Average Loss: 0.0762
# time 1.1 sec:
# Test set: Average loss: 0.0749, Accuracy: 2021/2069 (97.68%)
#
# Train Epoch: 28, Average Loss: 0.0715
# time 1.2 sec:
# Test set: Average loss: 0.0706, Accuracy: 2024/2069 (97.83%)
#
# Train Epoch: 29, Average Loss: 0.0644
# time 1.1 sec:
# Test set: Average loss: 0.0647, Accuracy: 2030/2069 (98.12%)
#
# Train Epoch: 30, Average Loss: 0.0589
# time 1.1 sec:
# Test set: Average loss: 0.0831, Accuracy: 2019/2069 (97.58%)
#
# Train Epoch: 31, Average Loss: 0.0661
# time 1.1 sec:
# Test set: Average loss: 0.0651, Accuracy: 2029/2069 (98.07%)
#
# Train Epoch: 32, Average Loss: 0.0562
# time 1.1 sec:
# Test set: Average loss: 0.0563, Accuracy: 2035/2069 (98.36%)
#
# Train Epoch: 33, Average Loss: 0.0535
# time 1.1 sec:
# Test set: Average loss: 0.0544, Accuracy: 2033/2069 (98.26%)
#
# Train Epoch: 34, Average Loss: 0.0495
# time 1.1 sec:
# Test set: Average loss: 0.0493, Accuracy: 2036/2069 (98.41%)
#
# Train Epoch: 35, Average Loss: 0.0459
# time 1.1 sec:
# Test set: Average loss: 0.0508, Accuracy: 2036/2069 (98.41%)
#
# Train Epoch: 36, Average Loss: 0.0415
# time 1.1 sec:
# Test set: Average loss: 0.0488, Accuracy: 2036/2069 (98.41%)
#
# Train Epoch: 37, Average Loss: 0.0413
# time 1.1 sec:
# Test set: Average loss: 0.0502, Accuracy: 2042/2069 (98.70%)
#
# Train Epoch: 38, Average Loss: 0.0412
# time 1.1 sec:
# Test set: Average loss: 0.0413, Accuracy: 2046/2069 (98.89%)
#
# Train Epoch: 39, Average Loss: 0.0386
# time 1.1 sec:
# Test set: Average loss: 0.0538, Accuracy: 2036/2069 (98.41%)
#
# Train Epoch: 40, Average Loss: 0.0370
# time 1.1 sec:
# Test set: Average loss: 0.0441, Accuracy: 2039/2069 (98.55%)
#
# Train Epoch: 41, Average Loss: 0.0365
# time 1.2 sec:
# Test set: Average loss: 0.0388, Accuracy: 2043/2069 (98.74%)
#
# Train Epoch: 42, Average Loss: 0.0373
# time 1.2 sec:
# Test set: Average loss: 0.0383, Accuracy: 2047/2069 (98.94%)
#
# Train Epoch: 43, Average Loss: 0.0314
# time 1.2 sec:
# Test set: Average loss: 0.0342, Accuracy: 2047/2069 (98.94%)
#
# Train Epoch: 44, Average Loss: 0.0339
# time 1.1 sec:
# Test set: Average loss: 0.0333, Accuracy: 2047/2069 (98.94%)
#
# Train Epoch: 45, Average Loss: 0.0316
# time 1.1 sec:
# Test set: Average loss: 0.0327, Accuracy: 2048/2069 (98.99%)
#
# Train Epoch: 46, Average Loss: 0.0309
# time 1.2 sec:
# Test set: Average loss: 0.0430, Accuracy: 2047/2069 (98.94%)
#
# Train Epoch: 47, Average Loss: 0.0330
# time 1.2 sec:
# Test set: Average loss: 0.0310, Accuracy: 2045/2069 (98.84%)
#
# Train Epoch: 48, Average Loss: 0.0310
# time 1.2 sec:
# Test set: Average loss: 0.0334, Accuracy: 2051/2069 (99.13%)
#
# Train Epoch: 49, Average Loss: 0.0328
# time 1.2 sec:
# Test set: Average loss: 0.0278, Accuracy: 2049/2069 (99.03%)
#
# Train Epoch: 50, Average Loss: 0.0247
# time 1.1 sec:
# Test set: Average loss: 0.0260, Accuracy: 2048/2069 (98.99%)
#
# Train Epoch: 51, Average Loss: 0.0214
# time 1.2 sec:
# Test set: Average loss: 0.0234, Accuracy: 2051/2069 (99.13%)
#
# Train Epoch: 52, Average Loss: 0.0217
# time 1.1 sec:
# Test set: Average loss: 0.0236, Accuracy: 2049/2069 (99.03%)
#
# Train Epoch: 53, Average Loss: 0.0220
# time 1.2 sec:
# Test set: Average loss: 0.0270, Accuracy: 2051/2069 (99.13%)
#
# Train Epoch: 54, Average Loss: 0.0185
# time 1.1 sec:
# Test set: Average loss: 0.0255, Accuracy: 2051/2069 (99.13%)
#
# Train Epoch: 55, Average Loss: 0.0213
# time 1.1 sec:
# Test set: Average loss: 0.0338, Accuracy: 2046/2069 (98.89%)
#
# Train Epoch: 56, Average Loss: 0.0196
# time 1.1 sec:
# Test set: Average loss: 0.0209, Accuracy: 2054/2069 (99.28%)
#
# Train Epoch: 57, Average Loss: 0.0183
# time 1.1 sec:
# Test set: Average loss: 0.0196, Accuracy: 2055/2069 (99.32%)
#
# Train Epoch: 58, Average Loss: 0.0188
# time 1.1 sec:
# Test set: Average loss: 0.0204, Accuracy: 2053/2069 (99.23%)
#
# Train Epoch: 59, Average Loss: 0.0197
# time 1.2 sec:
# Test set: Average loss: 0.0304, Accuracy: 2050/2069 (99.08%)
#
# Train Epoch: 60, Average Loss: 0.0224
# time 1.2 sec:
# Test set: Average loss: 0.0217, Accuracy: 2051/2069 (99.13%)
#
# Train Epoch: 61, Average Loss: 0.0189
# time 1.1 sec:
# Test set: Average loss: 0.0209, Accuracy: 2060/2069 (99.57%)
#
# Train Epoch: 62, Average Loss: 0.0165
# time 1.1 sec:
# Test set: Average loss: 0.0206, Accuracy: 2053/2069 (99.23%)
#
# Train Epoch: 63, Average Loss: 0.0154
# time 1.1 sec:
# Test set: Average loss: 0.0332, Accuracy: 2044/2069 (98.79%)
#
# Train Epoch: 64, Average Loss: 0.0172
# time 1.1 sec:
# Test set: Average loss: 0.0180, Accuracy: 2055/2069 (99.32%)
#
# Train Epoch: 65, Average Loss: 0.0135
# time 1.2 sec:
# Test set: Average loss: 0.0163, Accuracy: 2054/2069 (99.28%)
#
# Train Epoch: 66, Average Loss: 0.0146
# time 1.1 sec:
# Test set: Average loss: 0.0137, Accuracy: 2057/2069 (99.42%)
#
# Train Epoch: 67, Average Loss: 0.0119
# time 1.2 sec:
# Test set: Average loss: 0.0206, Accuracy: 2060/2069 (99.57%)
#
# Train Epoch: 68, Average Loss: 0.0144
# time 1.1 sec:
# Test set: Average loss: 0.0155, Accuracy: 2061/2069 (99.61%)
#
# Train Epoch: 69, Average Loss: 0.0115
# time 1.1 sec:
# Test set: Average loss: 0.0152, Accuracy: 2056/2069 (99.37%)
#
# Train Epoch: 70, Average Loss: 0.0105
# time 1.1 sec:
# Test set: Average loss: 0.0146, Accuracy: 2056/2069 (99.37%)
#
# Train Epoch: 71, Average Loss: 0.0122
# time 1.1 sec:
# Test set: Average loss: 0.0136, Accuracy: 2064/2069 (99.76%)
#
# Train Epoch: 72, Average Loss: 0.0139
# time 1.1 sec:
# Test set: Average loss: 0.0137, Accuracy: 2059/2069 (99.52%)
# Train Epoch: 73, Average Loss: 0.0123
# time 1.1 sec:
# Test set: Average loss: 0.0126, Accuracy: 2058/2069 (99.47%)
#
# Train Epoch: 74, Average Loss: 0.0111
# time 1.2 sec:
# Test set: Average loss: 0.0142, Accuracy: 2057/2069 (99.42%)
#
# Train Epoch: 75, Average Loss: 0.0097
# time 1.1 sec:
# Test set: Average loss: 0.0215, Accuracy: 2051/2069 (99.13%)
#
# Train Epoch: 76, Average Loss: 0.0141
# time 1.1 sec:
# Test set: Average loss: 0.0226, Accuracy: 2052/2069 (99.18%)
#
# Train Epoch: 77, Average Loss: 0.0122
# time 1.1 sec:
# Test set: Average loss: 0.0101, Accuracy: 2063/2069 (99.71%)
#
# Train Epoch: 78, Average Loss: 0.0103
# time 1.2 sec:
# Test set: Average loss: 0.0110, Accuracy: 2059/2069 (99.52%)
#
# Train Epoch: 79, Average Loss: 0.0099
# time 1.2 sec:
# Test set: Average loss: 0.0099, Accuracy: 2062/2069 (99.66%)
#
# Train Epoch: 80, Average Loss: 0.0095
# time 1.2 sec:
# Test set: Average loss: 0.0120, Accuracy: 2058/2069 (99.47%)
#
# Train Epoch: 81, Average Loss: 0.0100
# time 1.1 sec:
# Test set: Average loss: 0.0112, Accuracy: 2061/2069 (99.61%)
#
# Train Epoch: 82, Average Loss: 0.0070
# time 1.1 sec:
# Test set: Average loss: 0.0102, Accuracy: 2060/2069 (99.57%)
#
# Train Epoch: 83, Average Loss: 0.0095
# time 1.1 sec:
# Test set: Average loss: 0.0108, Accuracy: 2061/2069 (99.61%)
#
# Train Epoch: 84, Average Loss: 0.0088
# time 1.2 sec:
# Test set: Average loss: 0.0118, Accuracy: 2058/2069 (99.47%)
#
# Train Epoch: 85, Average Loss: 0.0085
# time 1.1 sec:
# Test set: Average loss: 0.0081, Accuracy: 2061/2069 (99.61%)
#
# Train Epoch: 86, Average Loss: 0.0099
# time 1.1 sec:
# Test set: Average loss: 0.0120, Accuracy: 2062/2069 (99.66%)
#
# Train Epoch: 87, Average Loss: 0.0089
# time 1.2 sec:
# Test set: Average loss: 0.0169, Accuracy: 2055/2069 (99.32%)
#
# Train Epoch: 88, Average Loss: 0.0086
# time 1.2 sec:
# Test set: Average loss: 0.0084, Accuracy: 2061/2069 (99.61%)
#
# Train Epoch: 89, Average Loss: 0.0069
# time 1.1 sec:
# Test set: Average loss: 0.0102, Accuracy: 2059/2069 (99.52%)
#
# Train Epoch: 90, Average Loss: 0.0081
# time 1.1 sec:
# Test set: Average loss: 0.0096, Accuracy: 2061/2069 (99.61%)
#
# Train Epoch: 91, Average Loss: 0.0075
# time 1.3 sec:
# Test set: Average loss: 0.0097, Accuracy: 2058/2069 (99.47%)
#
# Train Epoch: 92, Average Loss: 0.0099
# time 1.2 sec:
# Test set: Average loss: 0.0083, Accuracy: 2063/2069 (99.71%)
#
# Train Epoch: 93, Average Loss: 0.0088
# time 1.1 sec:
# Test set: Average loss: 0.0082, Accuracy: 2060/2069 (99.57%)
#
# Train Epoch: 94, Average Loss: 0.0065
# time 1.1 sec:
# Test set: Average loss: 0.0120, Accuracy: 2059/2069 (99.52%)
#
# Train Epoch: 95, Average Loss: 0.0074
# time 1.2 sec:
# Test set: Average loss: 0.0294, Accuracy: 2052/2069 (99.18%)
#
# Train Epoch: 96, Average Loss: 0.0084
# time 1.1 sec:
# Test set: Average loss: 0.0077, Accuracy: 2064/2069 (99.76%)
#
# Train Epoch: 97, Average Loss: 0.0077
# time 1.2 sec:
# Test set: Average loss: 0.0124, Accuracy: 2059/2069 (99.52%)
#
# Train Epoch: 98, Average Loss: 0.0078
# time 1.1 sec:
# Test set: Average loss: 0.0132, Accuracy: 2060/2069 (99.57%)
#
# Train Epoch: 99, Average Loss: 0.0094
# time 1.1 sec:
# Test set: Average loss: 0.0134, Accuracy: 2059/2069 (99.52%)
#
# Train Epoch: 100, Average Loss: 0.0063
# time 1.2 sec:
# Test set: Average loss: 0.0097, Accuracy: 2061/2069 (99.61%)
#
# CPU times: user 1min 49s, sys: 20.2 s, total: 2min 9s
# Wall time: 2min 9s

# %%
model.eval()
y_pred = []
y_test = []
with torch.no_grad():
    for data, target in test_loader:
        data = data.cuda()
        output = model(data)
        pred = output.max(1, keepdim=True)[1]  
        pred = pred.cpu().numpy().squeeze()
        y_pred.append(pred)
        y_test.append(target.numpy().squeeze())
y_pred=np.hstack(y_pred)
y_test=np.hstack(y_test)

summary(y_pred,y_test)
# Out:
# confusion matrix:
#  [[1835    9]
#  [   2  223]]
# Roc score: 0.9931
# F1 score: 0.9759
# Recall_score: 0.9911
# Precision_score: 0.9612
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1844
#            1       0.96      0.99      0.98       225
#
#     accuracy                           0.99      2069
#    macro avg       0.98      0.99      0.99      2069
# weighted avg       0.99      0.99      0.99      2069

# %%
torch.save(model, './models/MCRNN.pth')
